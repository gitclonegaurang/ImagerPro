# %% [markdown]
# <h2 style='color:blue' align='center'> Imager Pro<h2>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./test_images/anurag_test.jpg')
img.shape
# Out:
# (4160, 3120, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (4160, 3120)

# %%
gray
# Out:
# array([[157, 158, 159, ..., 254, 254, 254],
#        [156, 156, 158, ..., 254, 254, 254],
#        [157, 158, 159, ..., 254, 254, 254],
#        ...,
#        [ 35,  37,  33, ...,  40,  42,  36],
#        [ 37,  37,  34, ...,  55,  59,  58],
#        [ 34,  31,  33, ...,  62,  60,  59]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[1696,  564,   56,   56],
#        [ 736, 1248, 1684, 1684]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (1696, 564, 56, 56)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (1684, 1684, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
# !pip install PyWavelets
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/anurag_test.jpg')
plt.imshow(original_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test_images/anurag_test.jpg')
plt.imshow(org_image_obstructed)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/DAnurag',
#  './dataset/Gaurang',
#  './dataset/Pranav',
#  './dataset/Tejas',
#  './dataset/Usmaan']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
person_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    person_name = img_dir.split('/')[-1]
    person_file_names_dict[person_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + person_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = person_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            person_file_names_dict[person_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/DAnurag
# Generating cropped images in folder:  ./dataset/cropped/Gaurang
# Generating cropped images in folder:  ./dataset/cropped/Pranav
# Generating cropped images in folder:  ./dataset/cropped/Tejas
# Generating cropped images in folder:  ./dataset/cropped/Usmaan

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
person_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    person_file_names_dict[celebrity_name] = file_list
person_file_names_dict
# Out:
# {'DAnurag': ['./dataset/cropped/DAnurag\\DAnurag1.png',
#   './dataset/cropped/DAnurag\\DAnurag10.png',
#   './dataset/cropped/DAnurag\\DAnurag11.png',
#   './dataset/cropped/DAnurag\\DAnurag12.png',
#   './dataset/cropped/DAnurag\\DAnurag13.png',
#   './dataset/cropped/DAnurag\\DAnurag14.png',
#   './dataset/cropped/DAnurag\\DAnurag15.png',
#   './dataset/cropped/DAnurag\\DAnurag16.png',
#   './dataset/cropped/DAnurag\\DAnurag17.png',
#   './dataset/cropped/DAnurag\\DAnurag18.png',
#   './dataset/cropped/DAnurag\\DAnurag19.png',
#   './dataset/cropped/DAnurag\\DAnurag2.png',
#   './dataset/cropped/DAnurag\\DAnurag20.png',
#   './dataset/cropped/DAnurag\\DAnurag21.png',
#   './dataset/cropped/DAnurag\\DAnurag22.png',
#   './dataset/cropped/DAnurag\\DAnurag23.png',
#   './dataset/cropped/DAnurag\\DAnurag24.png',
#   './dataset/cropped/DAnurag\\DAnurag25.png',
#   './dataset/cropped/DAnurag\\DAnurag26.png',
#   './dataset/cropped/DAnurag\\DAnurag27.png',
#   './dataset/cropped/DAnurag\\DAnurag3.png',
#   './dataset/cropped/DAnurag\\DAnurag4.png',
#   './dataset/cropped/DAnurag\\DAnurag5.png',
#   './dataset/cropped/DAnurag\\DAnurag6.png',
#   './dataset/cropped/DAnurag\\DAnurag7.png',
#   './dataset/cropped/DAnurag\\DAnurag8.png',
#   './dataset/cropped/DAnurag\\DAnurag9.png'],
#  'Gaurang': ['./dataset/cropped/Gaurang\\Gaurang1.png',
#   './dataset/cropped/Gaurang\\Gaurang10.png',
#   './dataset/cropped/Gaurang\\Gaurang11.png',
#   './dataset/cropped/Gaurang\\Gaurang12.png',
#   './dataset/cropped/Gaurang\\Gaurang13.png',
#   './dataset/cropped/Gaurang\\Gaurang14.png',
#   './dataset/cropped/Gaurang\\Gaurang15.png',
#   './dataset/cropped/Gaurang\\Gaurang16.png',
#   './dataset/cropped/Gaurang\\Gaurang17.png',
#   './dataset/cropped/Gaurang\\Gaurang18.png',
#   './dataset/cropped/Gaurang\\Gaurang19.png',
#   './dataset/cropped/Gaurang\\Gaurang2.png',
#   './dataset/cropped/Gaurang\\Gaurang20.png',
#   './dataset/cropped/Gaurang\\Gaurang21.png',
#   './dataset/cropped/Gaurang\\Gaurang22.png',
#   './dataset/cropped/Gaurang\\Gaurang23.png',
#   './dataset/cropped/Gaurang\\Gaurang24.png',
#   './dataset/cropped/Gaurang\\Gaurang25.png',
#   './dataset/cropped/Gaurang\\Gaurang26.png',
#   './dataset/cropped/Gaurang\\Gaurang27.png',
#   './dataset/cropped/Gaurang\\Gaurang28.png',
#   './dataset/cropped/Gaurang\\Gaurang29.png',
#   './dataset/cropped/Gaurang\\Gaurang3.png',
#   './dataset/cropped/Gaurang\\Gaurang30.png',
#   './dataset/cropped/Gaurang\\Gaurang4.png',
#   './dataset/cropped/Gaurang\\Gaurang5.png',
#   './dataset/cropped/Gaurang\\Gaurang6.png',
#   './dataset/cropped/Gaurang\\Gaurang7.png',
#   './dataset/cropped/Gaurang\\Gaurang8.png',
#   './dataset/cropped/Gaurang\\Gaurang9.png'],
#  'Pranav': ['./dataset/cropped/Pranav\\Pranav1.png',
#   './dataset/cropped/Pranav\\Pranav10.png',
#   './dataset/cropped/Pranav\\Pranav11.png',
#   './dataset/cropped/Pranav\\Pranav12.png',
#   './dataset/cropped/Pranav\\Pranav13.png',
#   './dataset/cropped/Pranav\\Pranav14.png',
#   './dataset/cropped/Pranav\\Pranav15.png',
#   './dataset/cropped/Pranav\\Pranav16.png',
#   './dataset/cropped/Pranav\\Pranav17.png',
#   './dataset/cropped/Pranav\\Pranav18.png',
#   './dataset/cropped/Pranav\\Pranav19.png',
#   './dataset/cropped/Pranav\\Pranav2.png',
#   './dataset/cropped/Pranav\\Pranav20.png',
#   './dataset/cropped/Pranav\\Pranav21.png',
#   './dataset/cropped/Pranav\\Pranav22.png',
#   './dataset/cropped/Pranav\\Pranav23.png',
#   './dataset/cropped/Pranav\\Pranav24.png',
#   './dataset/cropped/Pranav\\Pranav25.png',
#   './dataset/cropped/Pranav\\Pranav26.png',
#   './dataset/cropped/Pranav\\Pranav27.png',
#   './dataset/cropped/Pranav\\Pranav28.png',
#   './dataset/cropped/Pranav\\Pranav29.png',
#   './dataset/cropped/Pranav\\Pranav3.png',
#   './dataset/cropped/Pranav\\Pranav30.png',
#   './dataset/cropped/Pranav\\Pranav31.png',
#   './dataset/cropped/Pranav\\Pranav32.png',
#   './dataset/cropped/Pranav\\Pranav33.png',
#   './dataset/cropped/Pranav\\Pranav34.png',
#   './dataset/cropped/Pranav\\Pranav35.png',
#   './dataset/cropped/Pranav\\Pranav36.png',
#   './dataset/cropped/Pranav\\Pranav37.png',
#   './dataset/cropped/Pranav\\Pranav38.png',
#   './dataset/cropped/Pranav\\Pranav39.png',
#   './dataset/cropped/Pranav\\Pranav4.png',
#   './dataset/cropped/Pranav\\Pranav40.png',
#   './dataset/cropped/Pranav\\Pranav5.png',
#   './dataset/cropped/Pranav\\Pranav6.png',
#   './dataset/cropped/Pranav\\Pranav7.png',
#   './dataset/cropped/Pranav\\Pranav8.png',
#   './dataset/cropped/Pranav\\Pranav9.png'],
#  'Tejas': ['./dataset/cropped/Tejas\\Tejas1.png',
#   './dataset/cropped/Tejas\\Tejas10.png',
#   './dataset/cropped/Tejas\\Tejas11.png',
#   './dataset/cropped/Tejas\\Tejas12.png',
#   './dataset/cropped/Tejas\\Tejas13.png',
#   './dataset/cropped/Tejas\\Tejas14.png',
#   './dataset/cropped/Tejas\\Tejas15.png',
#   './dataset/cropped/Tejas\\Tejas16.png',
#   './dataset/cropped/Tejas\\Tejas17.png',
#   './dataset/cropped/Tejas\\Tejas18.png',
#   './dataset/cropped/Tejas\\Tejas19.png',
#   './dataset/cropped/Tejas\\Tejas2.png',
#   './dataset/cropped/Tejas\\Tejas20.png',
#   './dataset/cropped/Tejas\\Tejas21.png',
#   './dataset/cropped/Tejas\\Tejas22.png',
#   './dataset/cropped/Tejas\\Tejas23.png',
#   './dataset/cropped/Tejas\\Tejas24.png',
#   './dataset/cropped/Tejas\\Tejas25.png',
#   './dataset/cropped/Tejas\\Tejas26.png',
#   './dataset/cropped/Tejas\\Tejas27.png',
#   './dataset/cropped/Tejas\\Tejas3.png',
#   './dataset/cropped/Tejas\\Tejas4.png',
#   './dataset/cropped/Tejas\\Tejas5.png',
#   './dataset/cropped/Tejas\\Tejas6.png',
#   './dataset/cropped/Tejas\\Tejas7.png',
#   './dataset/cropped/Tejas\\Tejas8.png',
#   './dataset/cropped/Tejas\\Tejas9.png'],
#  'Usmaan': ['./dataset/cropped/Usmaan\\Usmaan1.png',
#   './dataset/cropped/Usmaan\\Usmaan10.png',
#   './dataset/cropped/Usmaan\\Usmaan11.png',
#   './dataset/cropped/Usmaan\\Usmaan12.png',
#   './dataset/cropped/Usmaan\\Usmaan13.png',
#   './dataset/cropped/Usmaan\\Usmaan14.png',
#   './dataset/cropped/Usmaan\\Usmaan15.png',
#   './dataset/cropped/Usmaan\\Usmaan16.png',
#   './dataset/cropped/Usmaan\\Usmaan17.png',
#   './dataset/cropped/Usmaan\\Usmaan18.png',
#   './dataset/cropped/Usmaan\\Usmaan19.png',
#   './dataset/cropped/Usmaan\\Usmaan2.png',
#   './dataset/cropped/Usmaan\\Usmaan20.png',
#   './dataset/cropped/Usmaan\\Usmaan21.png',
#   './dataset/cropped/Usmaan\\Usmaan22.png',
#   './dataset/cropped/Usmaan\\Usmaan23.png',
#   './dataset/cropped/Usmaan\\Usmaan24.png',
#   './dataset/cropped/Usmaan\\Usmaan25.png',
#   './dataset/cropped/Usmaan\\Usmaan26.png',
#   './dataset/cropped/Usmaan\\Usmaan27.png',
#   './dataset/cropped/Usmaan\\Usmaan28.png',
#   './dataset/cropped/Usmaan\\Usmaan29.png',
#   './dataset/cropped/Usmaan\\Usmaan3.png',
#   './dataset/cropped/Usmaan\\Usmaan4.png',
#   './dataset/cropped/Usmaan\\Usmaan5.png',
#   './dataset/cropped/Usmaan\\Usmaan6.png',
#   './dataset/cropped/Usmaan\\Usmaan7.png',
#   './dataset/cropped/Usmaan\\Usmaan8.png',
#   './dataset/cropped/Usmaan\\Usmaan9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in person_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'DAnurag': 0, 'Gaurang': 1, 'Pranav': 2, 'Tejas': 3, 'Usmaan': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in person_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[221],
#        [228],
#        [237],
#        ...,
#        [ 25],
#        [ 25],
#        [  0]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (153, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8717948717948718

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83         6
#            1       1.00      0.50      0.67         8
#            2       0.71      1.00      0.83        10
#            3       1.00      1.00      1.00         9
#            4       1.00      1.00      1.00         6
#
#     accuracy                           0.87        39
#    macro avg       0.91      0.87      0.87        39
# weighted avg       0.90      0.87      0.86        39

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.719368
# 1        random_forest    0.580237
# 2  logistic_regression    0.807115
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8717948717948718

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.717948717948718

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.9230769230769231

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 5,  0,  1,  0,  0],
#        [ 2,  5,  1,  0,  0],
#        [ 0,  0, 10,  0,  0],
#        [ 0,  0,  0,  9,  0],
#        [ 1,  0,  0,  0,  5]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'DAnurag': 0, 'Gaurang': 1, 'Pranav': 2, 'Tejas': 3, 'Usmaan': 4}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model_new.pkl')
# Out:
# Requirement already satisfied: joblib in f:\miniconda3\envs\ztm_ml_course_env\lib\site-packages (1.2.0)
# ['saved_model_new.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
